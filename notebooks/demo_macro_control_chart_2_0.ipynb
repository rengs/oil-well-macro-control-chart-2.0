# %% [markdown]
# # Oil Well Macro Control Chart 2.0 Demo
#
# This notebook demonstrates loading sample well data and calculating macro-control indicators.

# %%
from pathlib import Path
import sys
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(ROOT / 'src'))
from calculate_indicators import calculate_indicators

df = pd.read_csv(ROOT / 'data' / 'sample_wells_500.csv')
result = calculate_indicators(df)
result.head()

# %%
result.groupby('control_zone')['well_id'].count()

# %%
result.sort_values('priority_score', ascending=False).head(10)[
    ['well_id', 'block', 'control_zone', 'measure_potential_score', 'priority_score']
]
